# %% [markdown]
# ## k- mean Clustering

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris

# %%
data=load_iris()
X=data.data

# %%
out=[]
for i in range(1,11):
    model=KMeans(n_clusters=i)
    model.fit(X)
    out.append(model.inertia_)
out
# Out:
# [681.3706,
#  152.3479517603579,
#  78.85566582597731,
#  57.38387326549494,
#  49.849814510523345,
#  41.81520454545456,
#  35.40640214360803,
#  32.239911312371845,
#  27.84678252449306,
#  27.148459983643804]

# %%
from kneed import KneeLocator
k_values=range(1,11)
kl=KneeLocator(k_values,out,curve='convex',direction='decreasing')
k=kl.elbow
k
# Out:
# np.int64(3)

# %%
plt.plot(k_values,out, marker='o', markerfacecolor='red', markeredgecolor='red')
plt.xlabel('K- values')
plt.ylabel('Inertia')
plt.title('Elbow curve')
# Out:
# Text(0.5, 1.0, 'Elbow curve')

# %%
model=KMeans(n_clusters=k)
model.fit(X)
# Out:
# KMeans(n_clusters=np.int64(3))

# %%
model.inertia_
centroids=model.cluster_centers_
labels=model.labels_

# %%
plt.scatter(X[:,0],X[:,1],c=labels)
plt.scatter(centroids[:,0],centroids[:,1],marker='*',s=100,c='red')
plt.xlabel('sepal length')
plt.ylabel('sepal width')
# Out:
# Text(0, 0.5, 'sepal width')

# %%
plt.scatter(X[:,2],X[:,3],c=labels)
plt.scatter(centroids[:,2],centroids[:,3],marker='*',s=100,c='red')
plt.xlabel('petal length')
plt.ylabel('petal width')
# Out:
# Text(0, 0.5, 'petal width')

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler

# %%
data2=load_breast_cancer()
x=data2.data
scaler=StandardScaler()
x=scaler.fit_transform(x)
df=pd.DataFrame(x,columns=data2.feature_names)
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0          3.283515        2.652874             2.532475       2.217515
# 1         -0.487072       -0.023846             0.548144       0.001392
# 2          1.052926        1.363478             2.037231       0.939685
# 3          3.402909        1.915897             1.451707       2.867383
# 4          0.539340        1.371011             1.428493      -0.009560
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
out=[]
for i in range(1,11):
    model=KMeans(n_clusters=i)
    model.fit(x)
    out.append(model.inertia_)
out
# Out:
# [17070.0,
#  11595.683312822135,
#  10061.797818243695,
#  9340.092708605138,
#  8906.56760052188,
#  8124.569301604039,
#  7587.473814653071,
#  7236.974390034589,
#  7292.170695104155,
#  6788.399996264889]

# %%
from kneed import KneeLocator
k_values=range(1,11)
kl=KneeLocator(k_values,out,curve='convex',direction='decreasing')
k=kl.elbow
k
# Out:
# np.int64(3)

# %%
plt.plot(k_values,out, marker='o', markerfacecolor='red', markeredgecolor='red')
plt.xlabel('K- values')
plt.ylabel('Inertia')
plt.title('Elbow curve')
# Out:
# Text(0.5, 1.0, 'Elbow curve')

# %%
model2=KMeans(n_clusters=k)
model2.fit(x)
# Out:
# KMeans(n_clusters=np.int64(3))

# %%
model.inertia_
centroid=model.cluster_centers_
label=model.labels_

# %%
plt.scatter(x[:,0],x[:,1],c=label)
plt.scatter(centroid[:,0],centroid[:,1],marker='*',s=400,c='red')

# %%
from sklearn.datasets import make_blobs

# %%
data =make_blobs(n_samples=100, n_features=5)
df=pd.DataFrame(data[0],columns=['x1','x2','x3','x4','x5'])
df.head()
xa=data[0]

# %%
out=[]
for i in range(1,11):
    model=KMeans(n_clusters=i)
    model.fit(xa)
    out.append(model.inertia_)
out
# Out:
# [15780.272893330339,
#  6553.671780573153,
#  480.13395359729554,
#  447.2706091839892,
#  411.0850860363086,
#  385.43727829975376,
#  378.5624181011561,
#  312.6960773282868,
#  297.59832195053605,
#  293.00374396041116]

# %%
from kneed import KneeLocator
k_values=range(1,11)
kl=KneeLocator(k_values,out,curve='convex',direction='decreasing')
k=kl.elbow
k
# Out:
# np.int64(3)

# %%
plt.plot(k_values,out, marker='o', markerfacecolor='red', markeredgecolor='red')
plt.xlabel('K- values')
plt.ylabel('Inertia')
plt.title('Elbow curve')
# Out:
# Text(0.5, 1.0, 'Elbow curve')

# %%
model3=KMeans(n_clusters=k)
model3.fit(xa)
# Out:
# KMeans(n_clusters=np.int64(3))

# %%
model.inertia_
centroid=model.cluster_centers_
label=model.labels_

# %%
plt.scatter(x[:,0],x[:,1],c=label)
plt.scatter(centroid[:,0],centroid[:,1],marker='*',s=100,c='red')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\axes\_axes.py:4761, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4760 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4761     colors = mcolors.to_rgba_array(c)
#    4762 except (TypeError, ValueError) as err:
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\colors.py:515, in to_rgba_array(c, alpha)
#     514 else:
# --> 515     rgba = np.array([to_rgba(cc) for cc in c])
#     517 if alpha is not None:
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\colors.py:317, in to_rgba(c, alpha)
#     316 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# ...
